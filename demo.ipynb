# %%
import matplotlib.pyplot as plt
import keras_ocr
import cv2
import time

# %%
# keras-ocr will automatically download pretrained
# weights for the detector and recognizer.
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /home/dedge/.keras-ocr/craft_mlt_25k.h5
# Looking for /home/dedge/.keras-ocr/crnn_kurapan.h5

# %%
# # Get a set of three example images
# images = [
#     keras_ocr.tools.read(url) for url in [
#         'https://upload.wikimedia.org/wikipedia/commons/b/bd/Army_Reserves_Recruitment_Banner_MOD_45156284.jpg',
#         'https://upload.wikimedia.org/wikipedia/commons/b/b4/EUBanana-500x112.jpg'
#     ]
# ]

images = [cv2.imread('./CBD_Images/test1.png'), cv2.imread('./CBD_Images/test2.png')]
# images = [cv2.imread('./CBD_Images/test1.png')]

# %%
# Each list of predictions in prediction_groups is a list of
# (word, box) tuples.
st = time.time()
prediction_groups = pipeline.recognize(images)
print("Inference Time: " + str(time.time()-st))
# Out:
# Inference Time: 18.231619596481323

# %%
# Plot the predictions
fig, axs = plt.subplots(nrows=len(images), figsize=(40, 40))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
